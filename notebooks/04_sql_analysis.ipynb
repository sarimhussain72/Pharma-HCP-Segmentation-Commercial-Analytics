# %% [markdown]
# # Pharmaceutical HCP Segmentation & Commercial Analytics
#
# ## Notebook 04 – SQL Business Analysis
#
# ### Objective
#
# This notebook contains SQL queries used to analyze healthcare professional (HCP) prescribing behavior, product performance, sales trends, and survey insights.
#
# The analysis answers real-world business questions that support commercial strategy and HCP targeting.
